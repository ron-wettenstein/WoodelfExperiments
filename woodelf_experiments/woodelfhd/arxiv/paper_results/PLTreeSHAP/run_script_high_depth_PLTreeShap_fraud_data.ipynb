# %% [markdown]
# # Run Python 3.8 script
#
# In the scripts below, we use PLTreeSHAP. The package depend on NumPy 1.24.0 and are incompatible with newer versions. Because of this dependency, they only support Python 3.8.
#
# However, Google Colab no longer supports Python 3.8, so we could not execute the code directly in the notebook. Instead, we created a Python 3.8 virtual environment (venv), installed all the required packages there — including pltreeshap — and ran our scripts within that environment.
#
# This is the best way I found to use PLTreeShap in Google Colab.

# %% [markdown]
# ## This notebook runs the `high_depth_FastPLTreeShap_fraud_data_script.py` script

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Copy out of Drive to an executable location
# !cp "/content/drive/MyDrive/CURRENT_DIR/PLTreeSHAP/run_python38_scripts.bash" /content/run_python38_scripts.bash

# (Optional but recommended) fix Windows CRLF line endings if present
# !sed -i 's/\r$//' /content/run_python38_scripts.bash

# Make it executable
# !chmod +x /content/run_python38_scripts.bash

# %% [markdown]
# Expect the script to run XX min (more or less...).

# %%
# !/content/run_python38_scripts.bash --pip "numpy==1.24.0 scipy pyarrow fastparquet pandas xgboost scikit-learn tqdm" --pip "Cython lightgbm" --pip "-v --no-build-isolation git+https://github.com/schufa-innovationlab/pltreeshap@main" --run "/content/drive/MyDrive/CURRENT_DIR/PLTreeSHAP/high_depth_FastPLTreeShap_fraud_data_script.py"
# Out:
# [py38-setup] Installing micromamba under /content/micromamba ...
#
# [py38-setup] Creating env 'py38' with Python 3.8 ...
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64   1%
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64  12%
# conda-forge/noarch    23%[+] 0.3s
# conda-forge/linux-64  22%
# conda-forge/noarch    55%[+] 0.4s
# conda-forge/linux-64  36%
# conda-forge/noarch    69%[+] 0.5s
# conda-forge/linux-64  43%
# conda-forge/noarch    99%conda-forge/noarch
# [+] 0.6s
# conda-forge/linux-64  58%[+] 0.7s
# conda-forge/linux-64  69%[+] 0.8s
# conda-forge/linux-64  74%[+] 0.9s
# conda-forge/linux-64  81%[+] 1.0s
# conda-forge/linux-64  88%[+] 1.1s
# conda-forge/linux-64  91%[+] 1.2s
# conda-forge/linux-64  96%conda-forge/linux-64
#
#
# Transaction
#
#   Prefix: /content/micromamba/envs/py38
#
#   Updating specs:
#
#    - python=3.8
#    - pip
#
#
#   Package               Version  Build                 Channel          Size
# ...
